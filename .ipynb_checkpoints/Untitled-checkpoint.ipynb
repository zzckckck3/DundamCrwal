# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
# 즈에진
options = Options()
options.add_experimental_option("detach", True)
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)

url = "https://dundam.xyz/main"
driver.get(url)
time.sleep(0.5)

driver.find_element(By.ID, "server").send_keys("모험단")
#==================================================#
# 여기 맨 끝 send_key(" 여기 ") 에 본인 모험단 입력#
#==================================================#
driver.find_element(By.XPATH, '//*[@id="main-page"]/div[1]/div[2]/div[2]/input').send_keys("즈에진")
time.sleep(0.5)
driver.find_element(By.NAME, "검색버튼").click()
time.sleep(0.5)

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

name = soup.select('div.seh_name > span.name')
level = soup.select('div.level > span.val')
damage = soup.select('div.seh_stat > ul > li:nth-child(1) > div > span.val')

nameList = []
levelList = []
damageList = []

# nameList 에 캐릭터 집어넣기
for i in range(len(name)):
    temp = name[i].text
    temp = temp[:6]
    temp = temp.replace('\n', '')
    temp = temp.replace(' ', '') 
    nameList.append(temp)

print(nameList)

for i in range(len(level)):
    temp = level[i].text
    levelList.append(temp)
    
print(levelList)

for i in range(len(damage)):
    temp = damage[i].text
    damageList.append(temp)
    
print(damageList)

#===========================================================================#
# 자기 모험단 이름에 맞춰서 값 수정하기#
#===========================================================================#
즈에진 = pd.DataFrame()
즈에진['닉네임'] = nameList
즈에진['명성'] = levelList
즈에진['데미지/버프력'] = damageList
# Out:
# ['즈에진', '쯔에', '주웨진', '즈에즈', '싀닉', '븜미마구베기', '이재징', '시니찬', '즈에징', '븜미죽여패기']
# ['43633', '42512', '41480', '42263', '39696', '38276', '37808', '36406', '33019', '33358']
# ['544.37 억', '375.27 억', '327.74 억', '743,786', '622,439', '201.26 억', '83.39 억', '60.95 억', '39.30 억', '29.62 억']

# %%
# 타 (지배당한주민)
options = Options()
options.add_experimental_option("detach", True)
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)

url = "https://dundam.xyz/main"
driver.get(url)
time.sleep(0.5)

driver.find_element(By.ID, "server").send_keys("모험단")
#==================================================#
# 여기 맨 끝 send_key(" 여기 ") 에 본인 모험단 입력#
#==================================================#
driver.find_element(By.XPATH, '//*[@id="main-page"]/div[1]/div[2]/div[2]/input').send_keys("타")
time.sleep(0.5)
driver.find_element(By.NAME, "검색버튼").click()
time.sleep(0.5)

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

name = soup.select('div.seh_name > span.name')
level = soup.select('div.level > span.val')
damage = soup.select('div.seh_stat > ul > li:nth-child(1) > div > span.val')

nameList = []
levelList = []
damageList = []

# nameList 에 캐릭터 집어넣기
for i in range(len(name)):
    temp = name[i].text
    temp = temp[:6]
    temp = temp.replace('\n', '')
    temp = temp.replace(' ', '') 
    nameList.append(temp)

print(nameList)

for i in range(len(level)):
    temp = level[i].text
    levelList.append(temp)
    
print(levelList)

for i in range(len(damage)):
    temp = damage[i].text
    damageList.append(temp)
    
print(damageList)

#===========================================================================#
# 자기 모험단 이름에 맞춰서 값 수정하기#
#===========================================================================#
타 = pd.DataFrame()
타['닉네임'] = nameList
타['명성'] = levelList
타['데미지/버프력'] = damageList
# Out:
# ['지배당한주민', '븜미마구차기', '헤응븜미쿨쿨', '키탕키타앙', '까마귀깎깎', '코모플', '요기요라이더', '팔이짧은인파', '용간핑챙', '한주두주세주']
# ['46955', '44217', '43223', '43107', '42409', '43388', '31881', '15664', '24720', '36288']
# ['636.42 억', '458.46 억', '778,140', '799,602', '407.36 억', '382.03 억', '95.37 억', '0.00 억', '25.32 억', '137.36 억']

# %%
# 드웨인존슨
options = Options()
options.add_experimental_option("detach", True)
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)

url = "https://dundam.xyz/main"
driver.get(url)
time.sleep(0.5)

driver.find_element(By.ID, "server").send_keys("모험단")
#==================================================#
# 여기 맨 끝 send_key(" 여기 ") 에 본인 모험단 입력#
#==================================================#
driver.find_element(By.XPATH, '//*[@id="main-page"]/div[1]/div[2]/div[2]/input').send_keys("드웨인존슨")
time.sleep(0.5)
driver.find_element(By.NAME, "검색버튼").click()
time.sleep(0.5)

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

name = soup.select('div.seh_name > span.name')
level = soup.select('div.level > span.val')
damage = soup.select('div.seh_stat > ul > li:nth-child(1) > div > span.val')

nameList = []
levelList = []
damageList = []

# nameList 에 캐릭터 집어넣기
for i in range(len(name)):
    temp = name[i].text
    temp = temp[:6]
    temp = temp.replace('\n', '')
    temp = temp.replace(' ', '') 
    nameList.append(temp)

print(nameList)

for i in range(len(level)):
    temp = level[i].text
    levelList.append(temp)
    
print(levelList)

for i in range(len(damage)):
    temp = damage[i].text
    damageList.append(temp)
    
print(damageList)

#===========================================================================#
# 자기 모험단 이름에 맞춰서 값 수정하기#
#===========================================================================#
드웨인존슨 = pd.DataFrame()
드웨인존슨['닉네임'] = nameList
드웨인존슨['명성'] = levelList
드웨인존슨['데미지/버프력'] = damageList
# Out:
# ['츠노드릴', '븝딱척살기', '쌍련창화추', '고급븝퍼', '광창검녀', '좌우출렁', '븜미마구잡기', '주광주', '출롱짱', '쮸쮸여왕', '로니콜먼', '캠보디아', '뀨레야']
# ['42938', '22072', '23239', '25678', '38549', '44355', '41763', '30488', '42885', '37985', '40409', '42798', '31583']
# ['437.86 억', '9.03 억', '0.00 억', '219,845', '193.55 억', '644.88 억', '333.03 억', '49.77 억', '393.82 억', '172.25 억', '365.84 억', '757,440', '80.62 억']

# %%
with pd.ExcelWriter('통합.xlsx') as writer:
    즈에진.to_excel(writer, sheet_name = '즈에진')
    타.to_excel(writer, sheet_name = '타')
    드웨인존슨.to_excel(writer, sheet_name = '드웨인존슨')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20908/3720652821.py in <module>
# ----> 1 with pd.ExcelWriter('통합.xlsx') as writer:
#       2     즈에진.to_excel(writer, sheet_name = '즈에진')
#       3     타.to_excel(writer, sheet_name = '타')
#       4     드웨인존슨.to_excel(writer, sheet_name = '드웨인존슨')
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_xlsxwriter.py in __init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#     189             raise ValueError("Append mode is not supported with xlsxwriter!")
#     190
# --> 191         super().__init__(
#     192             path,
#     193             engine=engine,
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#     923         self.handles = IOHandles(cast(Buffer, path), compression={"copression": None})
#     924         if not isinstance(path, ExcelWriter):
# --> 925             self.handles = get_handle(
#     926                 path, mode, storage_options=storage_options, is_text=False
#     927             )
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     709         else:
#     710             # Binary mode
# --> 711             handle = open(handle, ioargs.mode)
#     712         handles.append(handle)
#     713
#
# PermissionError: [Errno 13] Permission denied: '통합.xlsx'
